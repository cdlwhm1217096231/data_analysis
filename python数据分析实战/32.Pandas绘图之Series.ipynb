# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt

# %%
s1 = Series(np.random.randn(1000)).cumsum()
s2 = Series(np.random.randn(1000)).cumsum()
s = Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.cumsum()
# Out:
# 0     1
# 1     3
# 2     6
# 3    10
# 4    15
# dtype: int64

# %%
s1.plot(kind='line', grid=True, label='s1', title="This is Series", style='--')
s2.plot(label='s2')

# %%
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(2, 1)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E03BCC0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E074198>],
#       dtype=object)

# %%
ax[0].plot(s1)

# %%
ax[1].plot(s2)

# %%
plt.show()

# %%
fig, ax = plt.subplots(2, 1)

# %%
s1[0:10].plot(ax=ax[0], label='s1', kind='Bar')
s1.plot(ax=ax[1], label='s2')

# %%
plt.show()
